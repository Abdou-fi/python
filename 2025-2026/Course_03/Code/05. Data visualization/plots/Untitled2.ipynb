# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.01)
y = np.sqrt(x)
z = np.cos(x)
h = np.sin(x)
plt.plot(x, y)
plt.plot(x, z)
plt.plot(x, h)
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_28968\334049311.py:5: RuntimeWarning: invalid value encountered in sqrt
#   y = np.sqrt(x)
