# %% [markdown]
# Example
#
# Get your own Python Server
# Search the string to see if it starts with "The" and ends with "Spain":

# %%
import re

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
# Out:
# Running cells with '.venv (Python 3.14.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Private/GitHub/pythonCourse/2025-2026/Course_04/03_RegEx/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ## RegEx Functions
#
# The re module offers a set of functions that allows us to search a string for a match:
#
# findall:	    Returns a list containing all matches
#
# search:	    Returns a Match object if there is a match anywhere in the string
#
# split: 	    Returns a list where the string has been split at each match
#
# sub:	        Replaces one or many matches with a string

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Flags
#
# You can add flags to the pattern when using regular expressions.

# %% [markdown]
# ![image.png](attachment:image.png)
